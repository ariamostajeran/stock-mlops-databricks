# %%
# %pip install kagglehub

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("journeyyouyeonkim/microsoft-tesla-finance-news-articles2020-2024")

print("Path to dataset files:", path)

# %%
import os

path = "/home/spark-94100a12-1ac2-48e5-bbc6-6d/.cache/kagglehub/datasets/journeyyouyeonkim/microsoft-tesla-finance-news-articles2020-2024/versions/1"

files = os.listdir(path)
print(files)

# %%
import pandas as pd

file_path = f"{path}/tsla_articles.csv"

historical_raw_df = pd.read_csv(file_path)

print("Columns:", historical_raw_df.columns.tolist())
print("Rows:", len(historical_raw_df))
historical_raw_df.head()
